# %% [markdown]
# # 🌍 Simple Disaster COG Processing - Optical Data Version
#
# This simplified notebook converts disaster satellite imagery to Cloud Optimized GeoTIFFs (COGs) with just a few cells.
#
# ## ✨ Features
# - **See files first** - List S3 files before configuring
# - **Smart configuration** - Define filename functions after seeing actual files
# - **Auto-discovery** - Automatically categorizes your files
# - **Simple processing** - Just run the cells in order
#
# ---

# %% [markdown]
# ## 📋 Step 1: Basic Configuration
#
# Set your event details and S3 paths:

# %%
# ========================================
# INPUTS
# ========================================

# S3 Paths to any optical RGB file
BUCKET = 'nasa-disasters'    # S3 bucket (DO NOT CHANGE)
DESTINATION_BASE = 'drcs_activations_new'  # Where to save COGs in S3 bucket (DO NOT CHANGE)
GEOTIFF_DIR = 'drcs_activations' # This is where all non-converted files should be placed
DESTINATION_PRODUCT = 'ISS' ## destimation will always have a capital letter

# Event Details
EVENT_NAME = 'ex_202405_Flood_Brazil'  # Your sensor or product name (e.g, Sentinel-1, Planet, Landsat)
SUB_PRODUCT_NAME = 'ISS'         #  PRODUCT_NAME (RGB, trueColor, SWIR, etc.). Can leave blank and it will read from PRODUCT_NAME.
SOURCE_PATH = f'{GEOTIFF_DIR}/{EVENT_NAME}/{SUB_PRODUCT_NAME}'      # Where your files are


# Processing Options
OVERWRITE = False      # Set to True to replace existing files
VERIFY = True          # Set to True to verify results after processing
SAVE_RESULTS = True    # Set to False to skip saving results CSV to /output directory

#print(f"Event: {GEOTIFF_DIR}")
print(f"Source: s3://{BUCKET}/{SOURCE_PATH}")
print(f"Destination: s3://{BUCKET}/{DESTINATION_BASE}/{DESTINATION_PRODUCT}")
# Out:
# Source: s3://nasa-disasters/event_testing/exercises/DaNCE/Flooding_Mar2026/2_Brazil/ex_202405_Flood_Brazil/ISS
# Destination: s3://nasa-disasters/drcs_activations_new/ISS

# %% [markdown]
# ## 🔍 Step 2: Connect to S3 and List Files
#
# Let's see what files are available before configuring filename transformations:

# %%
# Import necessary modules
import sys
import os
from pathlib import Path

# Add parent directory to path for importing functions
sys.path.insert(0, str(Path('..').resolve()))

# Import S3 operations
from core.s3_operations import (
    initialize_s3_client,
    list_s3_files,
    get_file_size_from_s3
)

# Initialize S3 client
print("🌐 Connecting to S3...")
s3_client, _ = initialize_s3_client(bucket_name=BUCKET, verbose=False)

if s3_client:
    print("✅ Connected to S3\n")
    
    # List all TIF files
    print(f"📂 Files in s3://{BUCKET}/{SOURCE_PATH}:")
    print("="*60)
    
    files = list_s3_files(s3_client, BUCKET, SOURCE_PATH, suffix='.tif')
    
    if files:
        print(f"Found {len(files)} .tif files:\n")
        for i, file_path in enumerate(files[:10], 1):  # Show first 10
            filename = os.path.basename(file_path)
            try:
                size_gb = get_file_size_from_s3(s3_client, BUCKET, file_path)
                print(f"{i:2}. {filename:<60} ({size_gb:.2f} GB)")
            except:
                print(f"{i:2}. {filename}")
        
        if len(files) > 10:
            print(f"\n... and {len(files) - 10} more files")
        
        print("\n" + "="*60)
        print("\n💡 Use this information to create filename functions in Step 3")
    else:
        print("⚠️ No .tif files found in the specified path.")
        print("   Check your SOURCE_PATH configuration.")
else:
    print("❌ Could not connect to S3. Check your AWS credentials.")
    files = []
# Out:
# 🌐 Connecting to S3...
# ✅ Connected to S3
#
# 📂 Files in s3://nasa-disasters/event_testing/exercises/DaNCE/Flooding_Mar2026/2_Brazil/ex_202405_Flood_Brazil/ISS:
# ============================================================
# ⚠️ No .tif files found in the specified path.
#    Check your SOURCE_PATH configuration.

# %% [markdown]
# ## 🔐 Step 2.5 (Optional): Enable Upload Permissions
#
# By default, S3 authentication uses **read-only** credentials. To enable **upload permissions** for processing files, you need to configure an external ID.
#
# ### Why External ID?
# The external ID acts like a password that allows you to assume an AWS role with upload permissions. Without it, you can read files but cannot write processed COGs back to S3.
#
# ### Setup Instructions:
# 1. Copy the template file to create your credentials file
# 2. Add the external ID (get this from your administrator)
#
# Run the cell below to check your current authentication status:

# %%
# Check if external ID is configured for upload permissions
import os
from pathlib import Path

# Path to credentials file
creds_dir = Path('..')
creds_file = creds_dir / 'aws_credentials.py'
example_file = creds_dir / 'aws_credentials.example.py'

print("🔐 Upload Permissions Status Check")
print("="*60)

os.listdir(creds_dir)

if creds_file.exists():
    print("✅ aws_credentials.py found")
    
    # Try to import and check if it's configured
    try:
        sys.path.insert(0, str(creds_dir))
        from aws_credentials import EXTERNAL_ID, UPLOAD_ROLE_ARN
        
        if EXTERNAL_ID and EXTERNAL_ID != "your-external-id-here":
            print("✅ External ID is configured")
            print("✅ You have UPLOAD permissions enabled")
            print(f"\n   Role: {UPLOAD_ROLE_ARN}")
            print("\n🎉 You're all set to upload processed files to S3!")
        else:
            print("⚠️ External ID not configured (still using placeholder)")
            print("⚠️ Currently using READ-ONLY credentials")
            print("\n📝 To enable uploads:")
            print(f"   1. Edit: {creds_file}")
            print("   2. Replace 'your-external-id-here' with actual external ID")
            print("   3. Restart kernel and re-run this notebook")
    except ImportError as e:
        print(f"⚠️ Could not import credentials: {e}")
        print("⚠️ Currently using READ-ONLY credentials")
else:
    print("⚠️ aws_credentials.py not found")
    print("⚠️ Currently using READ-ONLY credentials")
    print("\n📝 To enable upload permissions:")
    print("\n   Step 1: Copy the template file")
    print(f"   cp {example_file} {creds_file}")
    print("\n   Step 2: Edit aws_credentials.py and add your external ID:")
    print("   EXTERNAL_ID = 'your-actual-external-id-here'")
    print("\n   Step 3: Restart kernel and re-run this notebook")
    
    if example_file.exists():
        print(f"\n💡 Template file available at: {example_file}")
    else:
        print("\n⚠️ Template file not found - check repository structure")

print("\n" + "="*60)
print("💡 Note: Read-only access is sufficient for listing and")
print("   downloading files. Upload permissions are only needed")
print("   for saving processed COGs back to S3.")
# Out:
# 🔐 Upload Permissions Status Check
# ============================================================
# ✅ aws_credentials.py found
# ✅ External ID is configured
# ✅ You have UPLOAD permissions enabled
#
#    Role: arn:aws:iam::515966502221:role/Jupyterhub-Data-Upload
#
# 🎉 You're all set to upload processed files to S3!
#
# ============================================================
# 💡 Note: Read-only access is sufficient for listing and
#    downloading files. Upload permissions are only needed
#    for saving processed COGs back to S3.

# %% [markdown]
# ### Quick check to see if a file will upload to S3 with credentials and External ID

# %%
from test_upload import test_s3_upload
test_s3_upload()
# Out:
# 🧪 Testing S3 Upload Permissions
# ============================================================
#
# 1. Initializing S3 client...
# 🔑 Attempting to authenticate with external ID for upload permissions...
# ⚠️ Failed to authenticate with external ID: An error occurred (AccessDenied) when calling the AssumeRole operation: User: arn:aws:sts::515966502221:assumed-role/disasters-prod/botocore-session-1776105192 is not authorized to perform: sts:AssumeRole on resource: arn:aws:iam::515966502221:role/Jupyterhub-Data-Upload
#    Falling back to default credentials...
# ✅ S3 client initialized with default credentials (read-only access)
# ✅ Confirmed access to nasa-disasters bucket
# ✅ S3 filesystem (fsspec) initialized
#
# 2. Creating test file...
#    ✅ Created: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog/tmpq54mcq2j.txt
#
# 3. Uploading to S3...
#    [UPLOAD] Uploading 0.0 MB to s3://nasa-disasters/test_uploads/test.txt
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/test_uploads/test.txt
#
# ✅ SUCCESS! File uploaded to s3://nasa-disasters/test_uploads/test.txt
#
# 🎉 Upload permissions are working correctly!
#    You can now process and upload COG files.
#
# 4. Verifying upload...
#    ✅ File verified in S3 (120 bytes)
#
#    🧹 Cleaned up temporary file
#
# ============================================================
# True

# %% [markdown]
# ## 🏷️ Step 3a: Define Categorization and Filename Transformations
#
# Based on the files you see above, configure:
# 1. **Categorization patterns** - Regex patterns to identify file types
# 2. **Filename functions** - How to transform filenames
# 3. **Output directories** - Where each category should be saved

# %%
# ========================================
# CATEGORIZATION AND OUTPUT CONFIGURATION
# ========================================

import re

# STEP 1: Define how to extract dates from filenames
def extract_date_from_filename(filename):
    """Extract date from filename in YYYYMMDD format."""
    dates = re.findall(r'\d{8}', filename)
    if dates:
        date_str = dates[0]
        #return f"{date_str[0:4]}-{date_str[4:6]}-{date_str[6:8]}"
        return f"{date_str}"
    return None

# STEP 2: Define filename transformation functions for each category
def create_truecolor_filename(original_path, event_name):
    """Create filename for trueColor products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    print(stem)
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        print(stem_clean)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"

def create_colorinfrared_filename(original_path, event_name):
    """Create filename for colorInfrared products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    print('Stem', stem)
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        print('Stem_Clean', stem_clean)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"

def create_naturalcolor_filename(original_path, event_name):
    """Create filename for naturalColor products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"

def create_swir_filename(original_path, event_name):
    """Create filename for swirRGB products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"
    
def create_ndvi_filename(original_path, event_name):
    """Create filename for swirRGB products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"

def create_mndwi_filename(original_path, event_name):
    """Create filename for swirRGB products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"
    
def create_blackmarble_filename(original_path, event_name):
    """Create filename for blackmarble products."""
    filename = os.path.basename(original_path)
    stem = os.path.splitext(filename)[0]
    date = extract_date_from_filename(stem)
    
    if date:
        stem_clean = re.sub(r'_\d{8}', '', stem)
        return f"{event_name}_{stem_clean}_{date}_day.tif"
    return f"{event_name}_{stem}_day.tif"
    
# STEP 3: Configure categorization patterns (REQUIRED)
# These regex patterns determine which files belong to which category
CATEGORIZATION_PATTERNS = {
    'trueColor': r'trueColor|truecolor|true_color',
    'colorInfrared': r'colorInfrared|colorIR|color_infrared',
    'naturalColor': r'naturalColor|natural_color',
    'shortwaveIR': r'shortwaveInfrared|swir',
    'ndvi': r'NDVI|ndvi',
    'mndwi': r'mNDWI|mndwi|MNDWI',
    'blackmarble': r'BlackMarble',
    # Add patterns for ALL file types you want to process
    # Files not matching any pattern will be skipped with a warning
}

# STEP 4: Map categories to filename transformation functions
FILENAME_CREATORS = {
    'trueColor': create_truecolor_filename,
    'colorInfrared': create_colorinfrared_filename,
    'naturalColor': create_naturalcolor_filename,
    'shortwaveIR': create_swir_filename,
    'ndvi': create_ndvi_filename,
    'mndwi': create_mndwi_filename,
    'blackmarble':create_blackmarble_filename,
    # Must have an entry for each category in CATEGORIZATION_PATTERNS
}

# STEP 5: Specify output directories for each category
OUTPUT_DIRS = {
    'trueColor': f"{DESTINATION_PRODUCT}/trueColor",
    'colorInfrared': f"{DESTINATION_PRODUCT}/colorIR",
    'naturalColor': f"{DESTINATION_PRODUCT}/naturalColor",
    'shortwaveIR': f"{DESTINATION_PRODUCT}/shortwaveIR",
    'ndvi': f"{DESTINATION_PRODUCT}/NDVI",
    'mndwi': f"{DESTINATION_PRODUCT}/MNDWI",
    'blackmarble': f"{DESTINATION_PRODUCT}",
    # Must have an entry for each category in CATEGORIZATION_PATTERNS
}

# OPTIONAL: Specify no-data values (None = auto-detect)
NODATA_VALUES = {
    'trueColor': 0,
    'colorInfrared': 0,
    'naturalColor': 0,
    'shortwaveIR': 0,
    'ndvi': -9999,
    'mndwi': -9999,
    'blackmarble': -9999,
    
    # Leave empty or set to None for auto-detection
}

# %% [markdown]
# ## 🏷️ Step 3b: Test the new functions to verify what the inputs and outputs will be.

# %%
print("✅ Configuration defined")
print(f"\n📂 Categories and output paths:")
for category, path in OUTPUT_DIRS.items():
    pattern = CATEGORIZATION_PATTERNS.get(category, 'No pattern defined')
    print(f"   • {category}:")
    print(f"     Pattern: {pattern}")
    print(f"     Output:  {DESTINATION_BASE}/{path}")

# Test with sample filename if files exist
if files:
    sample_file = files[0]
    sample_name = os.path.basename(sample_file)
    
    # Check which category it would match
    matched_category = None
    for cat, pattern in CATEGORIZATION_PATTERNS.items():
        if re.search(pattern, sample_name, re.IGNORECASE):
            matched_category = cat
            break
    
    if matched_category:
        new_name = FILENAME_CREATORS[matched_category](sample_file, EVENT_NAME)
        print(f"\n📝 Example transformation:")
        print(f"   Original: {sample_name}")
        print(f"   Category: {matched_category}")
        print(f"   → New:    {new_name}")
        print(f"   → Output: {DESTINATION_BASE}/{OUTPUT_DIRS[matched_category]}/{new_name}")
    else:
        print(f"\n⚠️ Warning: Sample file doesn't match any category pattern:")
        print(f"   File: {sample_name}")
        print(f"   Add a pattern to CATEGORIZATION_PATTERNS to process this file type")
# Out:
# ✅ Configuration defined
#
# 📂 Categories and output paths:
#    • trueColor:
#      Pattern: trueColor|truecolor|true_color
#      Output:  drcs_activations_new/ISS/trueColor
#    • colorInfrared:
#      Pattern: colorInfrared|colorIR|color_infrared
#      Output:  drcs_activations_new/ISS/colorIR
#    • naturalColor:
#      Pattern: naturalColor|natural_color
#      Output:  drcs_activations_new/ISS/naturalColor
#    • shortwaveIR:
#      Pattern: shortwaveInfrared|swir
#      Output:  drcs_activations_new/ISS/shortwaveIR
#    • ndvi:
#      Pattern: NDVI|ndvi
#      Output:  drcs_activations_new/ISS/NDVI
#    • mndwi:
#      Pattern: mNDWI|mndwi|MNDWI
#      Output:  drcs_activations_new/ISS/MNDWI
#    • blackmarble:
#      Pattern: BlackMarble
#      Output:  drcs_activations_new/ISS

# %% [markdown]
# ## 🚀 Step 4: Initialize Processor and Preview
#
# Now let's set up the processor and preview all transformations:

# %%
# Import our simplified helper
from notebooks.notebook_helpers import SimpleProcessor

# Create full configuration with categorization patterns
config = {
    'event_name': EVENT_NAME,
    'bucket': BUCKET,
    'source_path': SOURCE_PATH,
    'destination_base': DESTINATION_BASE,
    'overwrite': OVERWRITE,
    'verify': VERIFY,
    'save_results': SAVE_RESULTS,  # Add save results flag
    'categorization_patterns': CATEGORIZATION_PATTERNS,  # IMPORTANT: Include patterns
    'filename_creators': FILENAME_CREATORS,
    'output_dirs': OUTPUT_DIRS,
    'nodata_values': NODATA_VALUES
}

# Initialize processor
processor = SimpleProcessor(config)

# Connect to S3 (already connected, but needed for processor)
if processor.connect_to_s3():
    print("✅ Processor ready\n")
    
    # Discover and categorize files
    num_files = processor.discover_files()
    
    if num_files > 0:
        # Show preview of transformations
        processor.preview_processing()
        
        print("\n📌 Review the transformations above.")
        print("   • Files will be saved to the directories specified in OUTPUT_DIRS")
        print("   • If files appear as 'uncategorized', add patterns to CATEGORIZATION_PATTERNS")
        print("   • When ready, proceed to Step 5 to process the files.")
    else:
        print("⚠️ No files found to process.")
else:
    print("❌ Could not initialize processor.")
# Out:
# ✅ All modules loaded successfully
#
# 🌐 Connecting to S3...
# ✅ Connected to S3 successfully
# ✅ Processor ready
#
#
# 🔍 Searching for files in: event_testing/exercises/DaNCE/Flooding_Mar2026/2_Brazil/ex_202405_Flood_Brazil/ISS
# ⚠️ No .tif files found
# ⚠️ No files found to process.

# %% [markdown]
# ## ⚙️ Step 5: Process Files
#
# Run this cell to start processing all files:

# %%
# Process all files
if 'num_files' in locals() and num_files > 0:
    print("🚀 Starting processing...")
    print("This may take several minutes depending on file sizes.\n")
    
    # Process everything
    results = processor.process_all()
    
    # Display results
    if not results.empty:
        print("\n📊 Processing Complete!")
        display(results) if 'display' in dir() else print(results)
else:
    print("⚠️ No files to process. Complete Steps 1-4 first.")
# Out:
# 🚀 Starting processing...
# This may take several minutes depending on file sizes.
#
#
# 🚀 Starting processing...
#
# 📦 Processing NDVI (4 files)
# ⚠️ No filename creator for NDVI, using default
#   ⚙️ Processing: Sentinel2_T18STD_NDVIMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_NDVIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 228.6 MB, Available: 28349.3 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_NDVIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_NDVIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 395.9 MB to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_NDVIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_NDVIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 261.5 MB (Change: +32.9 MB)
#    [TIME] Total processing time: 38.0 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_NDVIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STD_NDVIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STD_NDVIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18STE_NDVIMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_NDVIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 261.5 MB, Available: 28337.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_NDVIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_NDVIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 293.9 MB to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_NDVIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_NDVIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 260.3 MB (Change: -1.2 MB)
#    [TIME] Total processing time: 31.6 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_NDVIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STE_NDVIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STE_NDVIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18SUD_NDVIMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_NDVIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 260.3 MB, Available: 28329.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_NDVIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_NDVIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 211.5 MB to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_NDVIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_NDVIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 260.9 MB (Change: +0.6 MB)
#    [TIME] Total processing time: 27.1 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_NDVIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUD_NDVIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUD_NDVIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18SUE_NDVIMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_NDVIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 260.9 MB, Available: 28345.9 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_NDVIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_NDVIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 300.6 MB to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_NDVIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/NDVI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_NDVIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 263.7 MB (Change: +2.8 MB)
#    [TIME] Total processing time: 33.3 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_NDVIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUE_NDVIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUE_NDVIMasked__2018-09-18_day.tif
#
# 📦 Processing colorInfrared (4 files)
# Stem Sentinel2_T18STD_colorInfraredMasked_20180918
# Stem_Clean Sentinel2_T18STD_colorInfraredMasked
#   ⚙️ Processing: Sentinel2_T18STD_colorInfraredMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_colorInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 263.7 MB, Available: 28322.5 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_colorInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_colorInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 203.6 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_colorInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_colorInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.8 MB (Change: -0.9 MB)
#    [TIME] Total processing time: 34.1 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_colorInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STD_colorInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STD_colorInfraredMasked_20180918_day.tif
# Stem Sentinel2_T18STE_colorInfraredMasked_20180918
# Stem_Clean Sentinel2_T18STE_colorInfraredMasked
#   ⚙️ Processing: Sentinel2_T18STE_colorInfraredMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_colorInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.8 MB, Available: 28333.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_colorInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_colorInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 168.2 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_colorInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_colorInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.4 MB (Change: -0.4 MB)
#    [TIME] Total processing time: 29.7 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_colorInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STE_colorInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STE_colorInfraredMasked_20180918_day.tif
# Stem Sentinel2_T18SUD_colorInfraredMasked_20180918
# Stem_Clean Sentinel2_T18SUD_colorInfraredMasked
#   ⚙️ Processing: Sentinel2_T18SUD_colorInfraredMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_colorInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.4 MB, Available: 28332.0 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_colorInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_colorInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 93.5 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_colorInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_colorInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 264.0 MB (Change: +1.6 MB)
#    [TIME] Total processing time: 26.3 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_colorInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUD_colorInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUD_colorInfraredMasked_20180918_day.tif
# Stem Sentinel2_T18SUE_colorInfraredMasked_20180918
# Stem_Clean Sentinel2_T18SUE_colorInfraredMasked
#   ⚙️ Processing: Sentinel2_T18SUE_colorInfraredMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_colorInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 264.0 MB, Available: 28335.9 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_colorInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_colorInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 144.2 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_colorInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/colorIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_colorInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 263.9 MB (Change: -0.1 MB)
#    [TIME] Total processing time: 30.1 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_colorInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUE_colorInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUE_colorInfraredMasked_20180918_day.tif
#
# 📦 Processing MNDWI (4 files)
# ⚠️ No filename creator for MNDWI, using default
#   ⚙️ Processing: Sentinel2_T18STD_mNDWIMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_mNDWIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 263.9 MB, Available: 28331.6 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_mNDWIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_mNDWIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 98.0 MB to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_mNDWIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STD_mNDWIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 262.5 MB (Change: -1.4 MB)
#    [TIME] Total processing time: 8.9 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_mNDWIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STD_mNDWIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STD_mNDWIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18STE_mNDWIMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_mNDWIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.5 MB, Available: 28331.3 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_mNDWIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_mNDWIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 73.6 MB to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_mNDWIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18STE_mNDWIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 262.1 MB (Change: -0.4 MB)
#    [TIME] Total processing time: 7.5 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_mNDWIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STE_mNDWIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STE_mNDWIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18SUD_mNDWIMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_mNDWIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.1 MB, Available: 28326.5 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_mNDWIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_mNDWIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 53.7 MB to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_mNDWIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_mNDWIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 261.8 MB (Change: -0.3 MB)
#    [TIME] Total processing time: 6.4 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_mNDWIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUD_mNDWIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUD_mNDWIMasked__2018-09-18_day.tif
#   ⚙️ Processing: Sentinel2_T18SUE_mNDWIMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_mNDWIMasked__2018-09-18_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 261.8 MB, Available: 28299.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_mNDWIMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_mNDWIMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: -9999
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: float32 → Resampling: bilinear, Overviews: average
#    [GDAL-COG] Detected original nodata: 999.0
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using bilinear resampling...
#    [GDAL-COG] Remapping nodata: 999.0 → -9999
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 76.5 MB to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_mNDWIMasked__2018-09-18_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/indices/MNDWI/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_mNDWIMasked__2018-09-18_day.tif
#    [MEMORY] Final: 262.7 MB (Change: +0.9 MB)
#    [TIME] Total processing time: 8.2 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_mNDWIMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUE_mNDWIMasked__2018-09-18_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUE_mNDWIMasked__2018-09-18_day.tif
#
# 📦 Processing shortwaveIR (4 files)
#   ⚙️ Processing: Sentinel2_T18STD_shortwaveInfraredMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_shortwaveInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.7 MB, Available: 28337.8 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_shortwaveInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_shortwaveInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 57.5 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_shortwaveInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STD_shortwaveInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.6 MB (Change: -0.1 MB)
#    [TIME] Total processing time: 8.3 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_shortwaveInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STD_shortwaveInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STD_shortwaveInfraredMasked_20180918_day.tif
#   ⚙️ Processing: Sentinel2_T18STE_shortwaveInfraredMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_shortwaveInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.6 MB, Available: 28337.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_shortwaveInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_shortwaveInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 49.5 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_shortwaveInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18STE_shortwaveInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.6 MB (Change: +0.0 MB)
#    [TIME] Total processing time: 7.1 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_shortwaveInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STE_shortwaveInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STE_shortwaveInfraredMasked_20180918_day.tif
#   ⚙️ Processing: Sentinel2_T18SUD_shortwaveInfraredMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_shortwaveInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.6 MB, Available: 28324.9 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_shortwaveInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_shortwaveInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 25.5 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_shortwaveInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_shortwaveInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.5 MB (Change: -0.1 MB)
#    [TIME] Total processing time: 6.3 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_shortwaveInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUD_shortwaveInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUD_shortwaveInfraredMasked_20180918_day.tif
#   ⚙️ Processing: Sentinel2_T18SUE_shortwaveInfraredMasked_20180918.tif (0.1GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_shortwaveInfraredMasked_20180918_day.tif
#    [INFO] File size: 0.1 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.5 MB, Available: 28336.1 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_shortwaveInfraredMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 115.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_shortwaveInfraredMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 41.5 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_shortwaveInfraredMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/shortwaveIR/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_shortwaveInfraredMasked_20180918_day.tif
#    [MEMORY] Final: 262.6 MB (Change: +0.0 MB)
#    [TIME] Total processing time: 9.7 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_shortwaveInfraredMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUE_shortwaveInfraredMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUE_shortwaveInfraredMasked_20180918_day.tif
#
# 📦 Processing trueColor (4 files)
# Sentinel2_T18STD_trueColorMasked_20180918
# Sentinel2_T18STD_trueColorMasked
#   ⚙️ Processing: Sentinel2_T18STD_trueColorMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STD_trueColorMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 262.6 MB, Available: 28307.6 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_trueColorMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_trueColorMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 164.4 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STD_trueColorMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STD_trueColorMasked_20180918_day.tif
#    [MEMORY] Final: 263.9 MB (Change: +1.3 MB)
#    [TIME] Total processing time: 34.0 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STD_trueColorMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STD_trueColorMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STD_trueColorMasked_20180918_day.tif
# Sentinel2_T18STE_trueColorMasked_20180918
# Sentinel2_T18STE_trueColorMasked
#   ⚙️ Processing: Sentinel2_T18STE_trueColorMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STE_trueColorMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 263.9 MB, Available: 28323.8 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_trueColorMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_trueColorMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 135.8 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STE_trueColorMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18STE_trueColorMasked_20180918_day.tif
#    [MEMORY] Final: 265.7 MB (Change: +1.8 MB)
#    [TIME] Total processing time: 30.0 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18STE_trueColorMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18STE_trueColorMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18STE_trueColorMasked_20180918_day.tif
# Sentinel2_T18SUD_trueColorMasked_20180918
# Sentinel2_T18SUD_trueColorMasked
#   ⚙️ Processing: Sentinel2_T18SUD_trueColorMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_trueColorMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 265.7 MB, Available: 28329.8 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_trueColorMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_trueColorMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 86.2 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_trueColorMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUD_trueColorMasked_20180918_day.tif
#    [MEMORY] Final: 263.2 MB (Change: -2.5 MB)
#    [TIME] Total processing time: 26.4 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUD_trueColorMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUD_trueColorMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUD_trueColorMasked_20180918_day.tif
# Sentinel2_T18SUE_trueColorMasked_20180918
# Sentinel2_T18SUE_trueColorMasked
#   ⚙️ Processing: Sentinel2_T18SUE_trueColorMasked_20180918.tif (0.4GB)
#    [CHECK] Checking if file already exists in S3: s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_trueColorMasked_20180918_day.tif
#    [INFO] File size: 0.4 GB
#    [CONFIG] Using fixed chunks
#    [TEMP] Using temp directory: /home/jovyan/shared-public/disasters-cog-conversion/templates/temp_cog
#    [MEMORY] Initial: 263.2 MB, Available: 28333.8 MB
#    [DOWNLOAD] Downloading from S3...
#    [DOWNLOAD] Downloading from S3: s3://nasa-disasters/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_trueColorMasked_20180918.tif
#    [DOWNLOAD] ✅ Downloaded 460.0 MB to data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_trueColorMasked_20180918.tif
#    [OPTIMIZED] Using GDAL COG driver for maximum performance
#    [NODATA] Using manual no-data value: 0
#    [GDAL-COG] Creating COG with native GDAL driver...
#    [GDAL-COG] Data type: uint8 → Resampling: nearest, Overviews: mode
#    [GDAL-COG] Stage 1: Reprojecting to EPSG:4326 using nearest resampling...
#    [GDAL-COG] Stage 2: Creating COG...
#    [GDAL-COG] ✅ COG with reprojection created successfully
#    [GDAL-COG] ✅ COG created successfully
#    [UPLOAD] Uploading 119.6 MB to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_trueColorMasked_20180918_day.tif
#    [UPLOAD] ✅ Uploaded to s3://nasa-disasters/drcs_activations_new/Sentinel2/trueColor/ex_201809_Hurricane_Florence_Sentinel2_T18SUE_trueColorMasked_20180918_day.tif
#    [MEMORY] Final: 263.6 MB (Change: +0.4 MB)
#    [TIME] Total processing time: 30.2 seconds
#    [CLEANUP] Removed: data_download/drcs_activations/ex_201809_Hurricane_Florence/Sentinel2/Sentinel2_T18SUE_trueColorMasked_20180918.tif
#    [CLEANUP] Removed: cog_ex_201809_Hurricane_Florence_Sentinel2_T18SUE_trueColorMasked_20180918_day.tif
#   ✅ Complete: ex_201809_Hurricane_Florence_Sentinel2_T18SUE_trueColorMasked_20180918_day.tif
#
# ============================================================
# ✅ PROCESSING COMPLETE
# ============================================================
#
# Results:
#   ✅ Success: 20
#
# Processing time: 7.3 minutes
# Average per file: 21.8 seconds
#
# 📁 Results saved to: output/ex_201809_Hurricane_Florence/results_20260413_185432.csv
# ============================================================
#
# 📊 Processing Complete!
#                                           source_file       category   status  \
# 0            Sentinel2_T18STD_NDVIMasked_20180918.tif           NDVI  success
# 1            Sentinel2_T18STE_NDVIMasked_20180918.tif           NDVI  success
# 2            Sentinel2_T18SUD_NDVIMasked_20180918.tif           NDVI  success
# 3            Sentinel2_T18SUE_NDVIMasked_20180918.tif           NDVI  success
# 4   Sentinel2_T18STD_colorInfraredMasked_20180918.tif  colorInfrared  success
# 5   Sentinel2_T18STE_colorInfraredMasked_20180918.tif  colorInfrared  success
# 6   Sentinel2_T18SUD_colorInfraredMasked_20180918.tif  colorInfrared  success
# 7   Sentinel2_T18SUE_colorInfraredMasked_20180918.tif  colorInfrared  success
# 8           Sentinel2_T18STD_mNDWIMasked_20180918.tif          MNDWI  success
# 9           Sentinel2_T18STE_mNDWIMasked_20180918.tif          MNDWI  success
# 10          Sentinel2_T18SUD_mNDWIMasked_20180918.tif          MNDWI  success
# 11          Sentinel2_T18SUE_mNDWIMasked_20180918.tif          MNDWI  success
# 12  Sentinel2_T18STD_shortwaveInfraredMasked_20180...    shortwaveIR  success
# 13  Sentinel2_T18STE_shortwaveInfraredMasked_20180...    shortwaveIR  success
# 14  Sentinel2_T18SUD_shortwaveInfraredMasked_20180...    shortwaveIR  success
# 15  Sentinel2_T18SUE_shortwaveInfraredMasked_20180...    shortwaveIR  success
# 16      Sentinel2_T18STD_trueColorMasked_20180918.tif      trueColor  success
# 17      Sentinel2_T18STE_trueColorMasked_20180918.tif      trueColor  success
# 18      Sentinel2_T18SUD_trueColorMasked_20180918.tif      trueColor  success
# 19      Sentinel2_T18SUE_trueColorMasked_20180918.tif      trueColor  success
#
#                                       output_filename  \
# 0   ex_201809_Hurricane_Florence_Sentinel2_T18STD_...
# 1   ex_201809_Hurricane_Florence_Sentinel2_T18STE_...
# 2   ex_201809_Hurricane_Florence_Sentinel2_T18SUD_...
# 3   ex_201809_Hurricane_Florence_Sentinel2_T18SUE_...
# 4   ex_201809_Hurricane_Florence_Sentinel2_T18STD_...
# 5   ex_201809_Hurricane_Florence_Sentinel2_T18STE_...
# 6   ex_201809_Hurricane_Florence_Sentinel2_T18SUD_...
# 7   ex_201809_Hurricane_Florence_Sentinel2_T18SUE_...
# 8   ex_201809_Hurricane_Florence_Sentinel2_T18STD_...
# 9   ex_201809_Hurricane_Florence_Sentinel2_T18STE_...
# 10  ex_201809_Hurricane_Florence_Sentinel2_T18SUD_...
# 11  ex_201809_Hurricane_Florence_Sentinel2_T18SUE_...
# 12  ex_201809_Hurricane_Florence_Sentinel2_T18STD_...
# 13  ex_201809_Hurricane_Florence_Sentinel2_T18STE_...
# 14  ex_201809_Hurricane_Florence_Sentinel2_T18SUD_...
# 15  ex_201809_Hurricane_Florence_Sentinel2_T18SUE_...
# 16  ex_201809_Hurricane_Florence_Sentinel2_T18STD_...
# 17  ex_201809_Hurricane_Florence_Sentinel2_T18STE_...
# 18  ex_201809_Hurricane_Florence_Sentinel2_T18SUD_...
# 19  ex_201809_Hurricane_Florence_Sentinel2_T18SUE_...
#
#                                           output_path  time_seconds
# 0   s3://nasa-disasters/drcs_activations_new/indic...     38.205329
# 1   s3://nasa-disasters/drcs_activations_new/indic...     31.775499
# 2   s3://nasa-disasters/drcs_activations_new/indic...     27.341835
# 3   s3://nasa-disasters/drcs_activations_new/indic...     33.486427
# 4   s3://nasa-disasters/drcs_activations_new/Senti...     34.257227
# 5   s3://nasa-disasters/drcs_activations_new/Senti...     29.860813
# 6   s3://nasa-disasters/drcs_activations_new/Senti...     26.510487
# 7   s3://nasa-disasters/drcs_activations_new/Senti...     30.249640
# 8   s3://nasa-disasters/drcs_activations_new/indic...      9.054861
# 9   s3://nasa-disasters/drcs_activations_new/indic...      7.716709
# 10  s3://nasa-disasters/drcs_activations_new/indic...      6.538722
# 11  s3://nasa-disasters/drcs_activations_new/indic...      8.355226
# 12  s3://nasa-disasters/drcs_activations_new/Senti...      8.489222
# 13  s3://nasa-disasters/drcs_activations_new/Senti...      7.244816
# 14  s3://nasa-disasters/drcs_activations_new/Senti...      6.503605
# 15  s3://nasa-disasters/drcs_activations_new/Senti...      9.916464
# 16  s3://nasa-disasters/drcs_activations_new/Senti...     34.220286
# 17  s3://nasa-disasters/drcs_activations_new/Senti...     30.186520
# 18  s3://nasa-disasters/drcs_activations_new/Senti...     26.565333
# 19  s3://nasa-disasters/drcs_activations_new/Senti...     30.427340

# %%
# Analyze results
if 'results' in locals() and not results.empty:
    print("📊 PROCESSING STATISTICS")
    print("="*40)
    
    # Success rate
    total = len(results)
    success = len(results[results['status'] == 'success'])
    failed = len(results[results['status'] == 'failed'])
    skipped = len(results[results['status'] == 'skipped'])
    
    print(f"Total files: {total}")
    print(f"✅ Success: {success}")
    print(f"❌ Failed: {failed}")
    print(f"⏭️ Skipped: {skipped}")
    print(f"\nSuccess rate: {(success/total*100):.1f}%")
    
    # Failed files
    if failed > 0:
        print("\n❌ Failed files:")
        failed_df = results[results['status'] == 'failed']
        for idx, row in failed_df.iterrows():
            print(f"  - {row['source_file']}: {row.get('error', 'Unknown error')}")
    
    # Processing times
    if 'time_seconds' in results.columns:
        success_df = results[results['status'] == 'success']
        if not success_df.empty:
            avg_time = success_df['time_seconds'].mean()
            max_time = success_df['time_seconds'].max()
            print(f"\n⏱️ Timing:")
            print(f"Average: {avg_time:.1f} seconds per file")
            print(f"Slowest: {max_time:.1f} seconds")
else:
    print("No results to analyze. Run Step 5 first.")
# Out:
# 📊 PROCESSING STATISTICS
# ========================================
# Total files: 20
# ✅ Success: 20
# ❌ Failed: 0
# ⏭️ Skipped: 0
#
# Success rate: 100.0%
#
# ⏱️ Timing:
# Average: 21.8 seconds per file
# Slowest: 38.2 seconds

# %% [markdown]
# ## 💡 Tips & Troubleshooting
#
# ### Workflow Summary:
# 1. **Setup** - Clone disasters-aws-conversion repository (Step 0)
# 2. **Configure** basic settings (Step 1)
# 3. **List files** from S3 to see naming patterns (Step 2)
# 4. **Define functions** to transform filenames (Step 3)
# 5. **Preview** transformations (Step 4)
# 6. **Process** all files (Step 5)
# 7. **Review** results (Step 6)
#
# ### Common Issues:
#
# 1. **"ModuleNotFoundError: No module named 'core'" or import errors**
#    - Run Step 0 first to clone the disasters-aws-conversion repository
#    - Restart kernel and run all cells from the beginning
#
# 2. **"No files found"**
#    - Check `SOURCE_PATH` in Step 1
#    - Verify bucket permissions
#    - Ensure files have `.tif` extension
#
# 3. **Wrong filename transformations**
#    - Review actual filenames in Step 2
#    - Adjust functions in Step 3
#    - Re-run Step 4 to preview
#
# 4. **Files being skipped**
#    - Files already exist in destination
#    - Set `OVERWRITE = True` in Step 1
#
# 5. **Processing errors**
#    - Check AWS credentials
#    - Verify S3 write permissions
#    - Check available disk space for temp files
#
# ### Need More Control?
#
# Use the full template at `disaster_processing_template.ipynb` for:
# - Manual chunk configuration
# - Custom compression settings
# - Detailed memory management
# - Advanced processing options
